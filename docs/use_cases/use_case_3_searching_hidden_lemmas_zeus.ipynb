# %% [markdown]
# # Use Case 3: Searching for Hidden Lemmas (Zeus)

# %% [markdown]
# ## Table of content (ToC)<a class="anchor" id="TOC"></a>
# * <a href="#bullet1">1 - Introduction</a>
# * <a href="#bullet2">2 - Load TF with the N1904addons</a>
# * <a href="#bullet3">3 - Analysis</a>
#     * <a href="#bullet3x1">3.1 - Identify wordforms potentialy derived from multiple lemmas</a>
#     * <a href="#bullet3x2">3.2 - Examine words with multiple potential lemmas assigned</a>
#     * <a href="#bullet3x3">3.3 - Now look for 'hidden' instances of Zeus</a>
#     * <a href="#bullet3x4">3.4 - Examine the acknowledged occurences of Zeus in the GNT</a>
#     * <a href="#bullet3x5">3.5 - Take a closer look at the other Διὰ instances</a>
# * <a href="#bullet4">4 - Required libraries</a>
# * <a href="#bullet5">5 - Attribution and footnotes</a>
# * <a href="#bullet6">6 - Notebook version</a>

# %% [markdown]
# #  1 - Introduction <a class="anchor" id="bullet1"></a>
# ##### [Back to ToC](#TOC)
#
# This notebook first demonstrates how to quickly identify wordforms in the N1904-TF dataset that allow for multiple lemmatizations.  It then examines a case that is a misidentification (διά as Zeus).
#
# The trigger for this example is a blog post from the research group <a href="https://sdam-au.github.io/sdam-au/digital-pondering/2020/01/31/greek-texts.html" target="_blank">Social Dynamics in the Ancient Mediterranean (SDAM)</a> at Aarhus University. Theys reported that applying CLTK's <a href="https://docs.cltk.org/en/latest/cltk.lemmatize.html" targe="_blank">`lemmatizer.lemmatize()`</a> to Aristotle's works yielded over 5,000 instances of Zeus, a sharp contrast to the <a href="https://stephanus.tlg.uci.edu/" target="_blank">Thesaurus Linguae Graecae® (TLG)</a>, which lists only 48. They further concluded that this discrepancy is largely due to the lemmatizer mistakenly identifying the common preposition διά as a form of Zeus. <a href="#footnote1"><sup>1</sup></a>

# %% [markdown]
# # 2 - Load TF with the N1904addons <a class="anchor" id="bullet2"></a>
# ##### [Back to ToC](#TOC)
#
# The following codeblocks will load the N1904-TF dataset together with the standard N1904addons dataset.

# %%
# Load the autoreload extension to automatically reload modules before executing code
# %load_ext autoreload
# %autoreload 2

# %%
# Loading the Text-Fabric code
from tf.fabric import Fabric
from tf.app import use

# %%
# Load the N1904-TF app and data with the additional features
A = use ("CenterBLC/N1904", mod=["tonyjurg/N1904addons/tf/", "tonyjurg/N1904addons/detailed_set"], silence="terse", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#gdb630837ae89b9468c9e50d13bda05cfd3de4f18 offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/N1904/app</span>
# <b title="local commit">data:</b> <span title="#gdb630837ae89b9468c9e50d13bda05cfd3de4f18 offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/N1904/tf/1.0.0</span>
# <b title="local commit">data:</b> <span title="#81314a298deed163230c4aa4838ac3ba6b907358 offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/tonyjurg/N1904addons/tf/1.0.0</span>
# <b title="local commit">data:</b> <span title="#81314a298deed163230c4aa4838ac3ba6b907358 offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.6</a>, <a target="_blank" href="https://github.com/CenterBLC/N1904/blob/main/app" title="CenterBLC/N1904 app">CenterBLC/N1904/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/tree/main/docs/about.md" title="provenance of Nestle 1904 Greek New Testament">CenterBLC - N1904 1.0.0</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/greek.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/tree/main/docs/features/README.md" title="CenterBLC - N1904 feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>group</th>
#     <td>8945</td>
#     <td>7.01</td>
#     <td>46</td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>42506</td>
#     <td>8.36</td>
#     <td><i>258</i></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>106868</td>
#     <td>6.88</td>
#     <td><i>533</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>69007</td>
#     <td>1.90</td>
#     <td>95</td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>116178</td>
#     <td>1.60</td>
#     <td><i>135</i></td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b><github>tonyjurg/N1904addons/detailed_set</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_aug1_bc.tf">md10_aug1_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :aug1 line - augment in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_aug1_uc.tf">md10_aug1_uc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :aug1 line - augment in unicode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_case.tf">md10_case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 grammatical case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_degree.tf">md10_degree</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 degree (comparative/superlative)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_dialects.tf">md10_dialects</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 listed dialects</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_end_bc.tf">md10_end_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - ending in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_end_codes.tf">md10_end_codes</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - listed morph codes</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_end_flags.tf">md10_end_flags</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - listed morph flags</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_end_uc.tf">md10_end_uc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - ending in unicode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_gender.tf">md10_gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 grammatical gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_gram_dif.tf">md10_gram_dif</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 grammatical difference against N1904-TF (field)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_lem_base_bc.tf">md10_lem_base_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :lem line - base lemma in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_lem_base_uc.tf">md10_lem_base_uc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :lem line - base lemma in unicode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_lem_full_bc.tf">md10_lem_full_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :lem line - raw lemma (incl. homonym or pl-suffix) in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_lem_full_uc.tf">md10_lem_full_uc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :lem line - raw lemma (incl. homonym or pl-suffix) in unicode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# Display is setup for viewtype [syntax-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/syntax-view.md#start)
# See [here](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/viewtypes.md#start) for more information on viewtypes

# %%
# The following will push the Text-Fabric stylesheet to this notebook (to facilitate proper display with notebook viewer)
A.dh(A.getCss())
# Out:
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c

# %% [markdown]
# # 3 - Analysis <a class="anchor" id="bullet3"></a>
# ##### [Back to ToC](#TOC)

# %% [markdown]
# ## 3.1 - Identify wordforms potentialy derived from multiple lemmas <a class="anchor" id="bullet3x1"></a>

# %% [markdown]
# First step is to identify word nodes that can be derived from multiple lemmas. Obvious in reality a *specific* word instance is only derived from a single lemma.
#
# To identify the cases where a wordform can be derived form multiple lemmas, one can easily use feature <a href="https://tonyjurg.github.io/N1904addons/features/mm_num_lemmas.html" target="_blank">`mm_num_lemmas`</a>. Since this feature has datatype `int`, we can use numeric operators on its value.

# %%
verseNodes=A.search("word mm_num_lemmas>1")
# Out:
#   0.12s 57331 results

# %% [markdown]
# ## 3.2 - Examine words with multiple potential lemmas assigned<a class="anchor" id="bullet3x2"></a>

# %% [markdown]
# Now first construct a list by concatenating “static” and “dynamic” elements using list comprehensions and string formatting (f-strings). This list will contain all the features that we want to show in the syntax tree.

# %%
number_of_ms_sets=11 # Python range(start, stop) is start-inclusive, stop-exclusive.
morphFeaturesList = (
    ['lemma','morph','betacode']
    + [f'ms{i}_lem_full_uc' for i in range(1, number_of_ms_sets)]
    + [f'ms{i}_morph'       for i in range(1, number_of_ms_sets)]
)

# %% [markdown]
# The effect of this list comprehension can be easily checked:

# %%
morphFeaturesList
# Out:
# ['lemma',
#  'morph',
#  'betacode',
#  'ms1_lem_full_uc',
#  'ms2_lem_full_uc',
#  'ms3_lem_full_uc',
#  'ms4_lem_full_uc',
#  'ms5_lem_full_uc',
#  'ms6_lem_full_uc',
#  'ms7_lem_full_uc',
#  'ms8_lem_full_uc',
#  'ms9_lem_full_uc',
#  'ms10_lem_full_uc',
#  'ms1_morph',
#  'ms2_morph',
#  'ms3_morph',
#  'ms4_morph',
#  'ms5_morph',
#  'ms6_morph',
#  'ms7_morph',
#  'ms8_morph',
#  'ms9_morph',
#  'ms10_morph']

# %% [markdown]
# Now we can use this list as argument to `extraFeatures`.

# %%
A.show(verseNodes,start=1,end=1, extraFeatures=morphFeaturesList,queryFeatures=False)
# Out:
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/1/1" title="Show this on the website" sec="Matthew 1:1">Matthew 1:1</a></span></div><div class=" children pr-mode"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Matthew</span> <span title="chapter">1</span>:<span title="verse">1</span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span> \\ <span title="typems">modifier-scope</span> <span title="role">p</span> <span title="rule">NPofNP</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems">common</span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="lemma xft" ><span class="f">lemma=</span>βίβλος</span><span class="morph xft" ><span class="f">morph=</span>N-NSF</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu grc">Βίβλος </span></div><div class="features"><span class="lemma " ><span class="f">lemma=</span>βίβλος</span><span class="morph " ><span class="f">morph=</span>N-NSF</span><span class="betacode xft" ><span class="f">betacode=</span>*bi/blos</span><span class="ms1_lem_full_uc xft" ><span class="f">ms1_lem_full_uc=</span>βίβλος</span><span class="ms1_morph xft" ><span class="f">ms1_morph=</span>N-NSF</span><span class="ms2_lem_full_uc xft" ><span class="f">ms2_lem_full_uc=</span>Βίβλος</span><span class="ms2_morph xft" ><span class="f">ms2_morph=</span>N-NSM</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems">modifier-scope</span> <span title="role"></span> <span title="rule">NPofNP</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems">common</span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="lemma xft" ><span class="f">lemma=</span>γένεσις</span><span class="morph xft" ><span class="f">morph=</span>N-GSF</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">γενέσεως </span></div><div class="features"><span class="lemma " ><span class="f">lemma=</span>γένεσις</span><span class="morph " ><span class="f">morph=</span>N-GSF</span><span class="betacode xft" ><span class="f">betacode=</span>gene/sews</span><span class="ms1_lem_full_uc xft" ><span class="f">ms1_lem_full_uc=</span>γένεσις</span><span class="ms1_morph xft" ><span class="f">ms1_morph=</span>N-GSF-ATT</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems">group</span> <span title="role"></span> <span title="rule">Np-Appos</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <sp ...

# %% [markdown]
# In this display all the yellow blocks are word nodes that have more than one lemma associated with it.

# %% [markdown]
# ## 3.3 - Now look for 'hidden' instances of Zeus <a class="anchor" id="bullet3x3"></a>

# %% [markdown]
# Since the SDAM blog post reported that 'dia' resulted in many hits for Zeus, the same can be tried on the New Testament to see if there are cases of 'hidden' Zues references.
#
# A very simple way to retrieve all lemmas for διά in the current N1904-TF dataset is to use the <a href="https://centerblc.github.io/N1904/features/lemmatranslit.html" target="_blank">`lemmatranslit`</a> feature. However, this approach is simplistic, as it overlooks the relevance of accentual distinctions. In this case, it is used deliberately to illustrate how a flawed argument can arise.

# %%
zeusNodes=A.search("word lemmatranslit=dia")
# Out:
#   0.07s 667 results

# %% [markdown]
# One might be tempted to stop here and speculate about the number’s proximity to 666. However, a closer look at the first reported instances offers no support for any ‘hidden’ connection to Zeus.

# %%
A.show(zeusNodes,start=1,end=1, extraFeatures=morphFeaturesList,queryFeatures=False)
# Out:
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/1/22" title="Show this on the website" sec="Matthew 1:22">Matthew 1:22</a></span></div><div class=" children pr-mode"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Matthew</span> <span title="chapter">1</span>:<span title="verse">22</span></span></div><div class="children hor wrap "><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="children hor wrap "><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="cls"></span> <span title="role"></span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Subj-Pred</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">Subj</span> <span title="rela"></span> \\ <span title="typems">modifier-scope</span> <span title="role">s</span> <span title="rule">NP-all</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems">demonstrative</span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="lemma xft" ><span class="f">lemma=</span>οὗτος</span><span class="morph xft" ><span class="f">morph=</span>D-NSN</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Τοῦτο </span></div><div class="features"><span class="lemma " ><span class="f">lemma=</span>οὗτος</span><span class="morph " ><span class="f">morph=</span>D-NSN</span><span class="betacode xft" ><span class="f">betacode=</span>*tou=to</span><span class="ms1_lem_full_uc xft" ><span class="f">ms1_lem_full_uc=</span>οὗτος</span><span class="ms1_morph xft" ><span class="f">ms1_morph=</span>D-NSN/D-VSN/D-ASN</span></div></div></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="lemma xft" ><span class="f">lemma=</span>δέ</span><span class="morph xft" ><span class="f">morph=</span>CONJ</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">δὲ </span></div><div class="features"><span class="lemma " ><span class="f">lemma=</span>δέ</span><span class="morph " ><span class="f">morph=</span>CONJ</span><span class="betacode xft" ><span class="f">betacode=</span>de\</span><span class="ms1_lem_full_uc xft" ><span class="f">ms1_lem_full_uc=</span>δέ</span><span class="ms1_morph xft" ><span class="f">ms1_morph=</span>PRT</span></div></div></div></div><div class="contnr c2   l rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="cls"></span> <span title="role"></span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c2   l " ><div class="lbl c2 ...

# %% [markdown]
# ## 3.4 - Examine the acknowledged occurences of Zeus in the GNT <a class="anchor" id="bullet3x4"></a>

# %% [markdown]
# For this we first examine the exact for Morpheus reported for Acts 14:12 (Δία) and Acts 14:13 (Διὸς), as these are the two acknowledged instances of lemma ζεύς in the N1904-TF. Since we know the verses, the query is very simple.

# %%
actsNodes=A.search('verse book=Acts chapter=14 verse=12|13')
# Out:
#   0.01s 2 results

# %% [markdown]
# Now display the results using the previous build list `morphFeaturesList`.

# %%
A.show(actsNodes,start=1,end=1, extraFeatures=morphFeaturesList,queryFeatures=False)
# Out:
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Acts/14/12" title="Show this on the website" sec="Acts 14:12">Acts 14:12</a></span></div><div class=" children pr-mode"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Acts</span> <span title="chapter">14</span>:<span title="verse">12</span></span></div><div class="children hor wrap "><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">group </span> <span class=""><span title="typ">conjuncted</span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems">conjuncted-wg</span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="cls"></span> <span title="role"></span> <span title="junction">coordinate</span></span></div><div class="children hor wrap "><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Obj-Obj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction">coordinate</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="typems"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="features"><span class="lemma xft" ><span class="f">lemma=</span>καλέω</span><span class="morph xft" ><span class="f">morph=</span>V-IAI-3P</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐκάλουν </span></div><div class="features"><span class="lemma " ><span class="f">lemma=</span>καλέω</span><span class="morph " ><span class="f">morph=</span>V-IAI-3P</span><span class="betacode xft" ><span class="f">betacode=</span>e)ka/loun</span><span class="ms1_lem_full_uc xft" ><span class="f">ms1_lem_full_uc=</span>καλέω</span><span class="ms1_morph xft" ><span class="f">ms1_morph=</span>V-IAI-3P-ATT/V-IAI-1S-ATT</span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="lemma xft" ><span class="f">lemma=</span>τέ</span><span class="morph xft" ><span class="f">morph=</span>PRT</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τε </span></div><div class="features"><span class="lemma " ><span class="f">lemma=</span>τέ</span><span class="morph " ><span class="f">morph=</span>PRT</span><span class="betacode xft" ><span class="f">betacode=</span>te</span><span class="ms1_lem_full_uc xft" ><span class="f">ms1_lem_full_uc=</span>τε</span><span class="ms1_morph xft" ><span class="f">ms1_morph=</span>PRT</span><span class="ms2_lem_full_uc xft" ><span class="f">ms2_lem_full_uc=</span>σύ</span><span class="ms2_morph xft" ><span class="f">ms2_morph=</span>P-2AS</span></div></div></div></div><div class="contnr c2   l rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="cls" ...

# %% [markdown]
# The next step is to conduct a block wise search for all instances where Morpheus identifies Ζεύς as a potential lemma for a given wordform. The code block below compiles a list of such cases, accompanied by a rather mechanical translation of the corresponding verse. Within each translation, the portion corresponding to the alternative Ζεύς is marked by curley brackets.

# %%
BLOCK_RANGE  = range(1, 25)
lem_feat     = {b: Fs(f"md{b}_lem_base_uc")  for b in BLOCK_RANGE}

numOccurences=0
for wordNode in F.otype.s('word'):
    for block in BLOCK_RANGE:
        if lem_feat[block].v(wordNode) == "Ζεύς":
            numOccurences+=1
            verseNode = L.u(wordNode, 'verse')[0]
            transWords = []
            t=''
            for w in L.d(verseNode, 'word'):
                if w == wordNode:
                    t += ' {'+F.trans.v(w)+' / Zeus?}'
                else:
                    t = F.trans.v(w) or ''
# ('I_Peter', 5, 12) Διὰ in block=8 of 13 :  {Through / Zeus?} Silvanus to you the faithful brother as I regard [him] through few [words] I have written exhorting and testifying this to be [the] true grace - of God in which you stand
# ('Revelation', 17, 7) Διὰ in block=8 of 13 : And said to me the angel angel {Because of / Zeus?} why did you marvel I will tell you the mystery of the woman and of the beast - carrying her - having the seven heads and the ten horns
# Found 38 instances of Zues

# %% [markdown]
# This list of verses makes it clear that the standard interpretation is coherent, whereas substituting the marked parts with some reference to Zeus would render the sentences unintelligible. Obvious the two verses in Acts 14 are the exception, but they were already rendered as Zeus.

# %% [markdown]
# ## 3.5 - Take a closer look at the other Διὰ instances <a class="anchor" id="bullet3x5"></a>

# %% [markdown]
# Now let us examine the first case:
#
# > ('Matthew', 6, 25) Διὰ in block=8 of 13 :  {Because of / Zeus?} this I say to you not be anxious about the life of you what you should eat or what you should drink nor the body of you what you should put on Not the life more is than the food and the body than clothing
#
# So let us retrieve that verse:

# %%
zeusNodes=A.search('verse book=Matthew chapter=6 verse=25')
# Out:
#   0.00s 1 result

# %% [markdown]
# And show its syntax tree:

# %%
A.show(zeusNodes,start=1,end=1, extraFeatures=morphFeaturesList,queryFeatures=False)
# Out:
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/6/25" title="Show this on the website" sec="Matthew 6:25">Matthew 6:25</a></span></div><div class=" children pr-mode"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Matthew</span> <span title="chapter">6</span>:<span title="verse">25</span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">PP</span> <span title="function">Cmpl</span> <span title="rela"></span> \\ <span title="typems">wrapper-scope</span> <span title="role">adv</span> <span title="rule">PrepNp</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="lemma xft" ><span class="f">lemma=</span>διά</span><span class="morph xft" ><span class="f">morph=</span>PREP</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Διὰ </span></div><div class="features"><span class="lemma " ><span class="f">lemma=</span>διά</span><span class="morph " ><span class="f">morph=</span>PREP</span><span class="betacode xft" ><span class="f">betacode=</span>*dia\</span><span class="ms1_lem_full_uc xft" ><span class="f">ms1_lem_full_uc=</span>διά</span><span class="ms1_morph xft" ><span class="f">ms1_morph=</span>PREP</span><span class="ms2_lem_full_uc xft" ><span class="f">ms2_lem_full_uc=</span>Δίη</span><span class="ms2_morph xft" ><span class="f">ms2_morph=</span>N-NSF-A/N-VSF-A</span><span class="ms3_lem_full_uc xft" ><span class="f">ms3_lem_full_uc=</span>Δίη-πλ</span><span class="ms3_morph xft" ><span class="f">ms3_morph=</span>N-NDF/N-VDF/N-ADF</span><span class="ms4_lem_full_uc xft" ><span class="f">ms4_lem_full_uc=</span>Δίον</span><span class="ms4_morph xft" ><span class="f">ms4_morph=</span>N-NPN/N-VPN/N-APN</span><span class="ms5_lem_full_uc xft" ><span class="f">ms5_lem_full_uc=</span>Δῖα</span><span class="ms5_morph xft" ><span class="f">ms5_morph=</span>N-NPN/N-VPN/N-APN</span><span class="ms6_lem_full_uc xft" ><span class="f">ms6_lem_full_uc=</span>Δῖον</span><span class="ms6_morph xft" ><span class="f">ms6_morph=</span>N-NPN/N-VPN/N-APN</span><span class="ms7_lem_full_uc xft" ><span class="f">ms7_lem_full_uc=</span>Διεύς</span><span class="ms7_morph xft" ><span class="f">ms7_morph=</span>N-ASM-ATT</span><span class="ms8_lem_full_uc xft" ><span class="f">ms8_lem_full_uc=</span>Ζεύς</span><span class="ms8_morph xft" ><span class="f">ms8_morph=</span>N-PRI</span><span class="ms9_lem_full_uc xft" ><span class="f">ms9_lem_full_uc=</span>δῖος</span><span class="ms9_morph xft" ><span class="f">ms9_morph=</span>N-PRI/N-NPN/N-VPN/N-APN/N-NDF/N-VDF/N-ADF/N-NSF-A/N-VSF-A</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems">demonstrative</span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="lemma xft" ><span class="f">lemma=</span>οὗτος</span><span class="morph xft" ><span class="f">morph=</span>D-ASN</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῦτο </span></div><div class="features"><span class="lemma " ><span class="f">lemma=< ...

# %% [markdown]
# Notably, all the “hidden Zeus” instances occur at the beginning of a sentence, where Διὰ is capitalised. This likely prompted the Morpheus analyser to identify it as a potential reference to the deity. Additionally, the accent patterns differ between the preposition and the proper noun, marking a meaningful distinction that further disambiguates their interpretation. Hence the conclusion is that there are no 'hidden' references to Zeus in the Greek New Testament.

# %% [markdown]
# # 4 - Required libraries<a class="anchor" id="bullet4"></a>
# ##### [Back to ToC](#TOC)
#
# Since the scripts in this notebook utilize Text-Fabric, [it requires currently (Apr 2025) Python >=3.9.0](https://pypi.org/project/text-fabric) together with the following libraries installed in the environment:
#
#     none
#
# You can install any missing library from within Jupyter Notebook using either`pip` or `pip3`.

# %% [markdown]
# # 5 - Attribution and footnotes <a class="anchor" id="bullet5"></a>
# ##### [Back to ToC](#TOC)
#
# #### Attribution
#
# The [N1904-TF dataset](https://centerblc.github.io/N1904/) is available under the [MIT licence](https://github.com/CenterBLC/N1904/blob/main/LICENSE.md). Formal reference:
# > Tony Jurg, Saulo de Oliveira Cantanhêde, & Oliver Glanz. (2024). *CenterBLC/N1904: Nestle 1904 Text-Fabric data*. Zenodo. DOI: [10.5281/zenodo.13117911](https://doi.org/10.5281/zenodo.13117910).
#
# The N1904addons Text-Fabric dataset is published at [tonyjurg.github.io/N1904addons](https://tonyjurg.github.io/N1904addons/) and made available under the [Creative Commons Attribution 4.0 International (CC BY 4.0)](https://github.com/tonyjurg/N1904addons/blob/main/LICENSE.md) license.
#
# This Jupyter notebook is released under the [Creative Commons Attribution 4.0 International (CC BY 4.0)](https://github.com/tonyjurg/N1904addons/blob/main/LICENSE.md).
#
# #### Footnotes
#
# <a class="anchor" id="footnote1"></a><sup>1</sup> The SDAM blog is found on [https://sdam-au.github.io/sdam-au/digital-pondering/2020/01/31/greek-texts.html](https://sdam-au.github.io/sdam-au/digital-pondering/2020/01/31/greek-texts.html).

# %% [markdown]
# # 6 - Notebook version<a class="anchor" id="bullet6"></a>
# ##### [Back to ToC](#TOC)
#
# <div style="float: left;">
#   <table>
#     <tr>
#       <td><strong>Author</strong></td>
#       <td>Tony Jurg</td>
#     </tr>
#     <tr>
#       <td><strong>Version</strong></td>
#       <td>1.1</td>
#     </tr>
#     <tr>
#       <td><strong>Date</strong></td>
#       <td>July 24, 2025</td>
#     </tr>
#   </table>
# </div>
