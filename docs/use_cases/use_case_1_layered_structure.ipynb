# %% [markdown]
# # Use Case 1: Layered Structure of Morphological Analysis (N1904addons)

# %% [markdown]
# ## Table of content (ToC)<a class="anchor" id="TOC"></a>
#
# * <a href="#bullet1">1 - Introduction</a>
# * <a href="#bullet2">2 - Step 1: Setting up the environment</a>
# * <a href="#bullet3">3 - Step 2: Start at the meta level (mm*)</a>
# * <a href="#bullet4">4 - Step 3: Explore at the summary level (ms*)</a>
# * <a href="#bullet5">5 - Step 4: Deep dive at the detail level (md*)</a>
# * <a href="#bullet6">6 - Making it efficient</a>
# * <a href="#bullet7">7 - Attribution and footnotes</a>
# * <a href="#bullet8">8 - Notebook version</a>

# %% [markdown]
# # 1 - Introduction <a class="anchor" id="bullet1"></a>
# ##### [Back to ToC](#TOC)
#
# This notebook will provide you a compact overview of how the concept of [Morpheus TF feature classes](https://tonyjurg.github.io/N1904addons/using_the_morpheus_features.html) is helpfull. The example below shows you how to begin at the meta level, drill down to the summary level, and—when needed—inspect the full, detailed analytic blocks. Everything happens within a single environment that brings together the core N1904-TF dataset, the N1904addons module, and optionaly a set of detailed functions when desired.

# %% [markdown]
# # 2 - Step 1: Setting up the environment <a class="anchor" id="bullet2"></a>
# ##### [Back to ToC](#TOC)

# %% [markdown]
# First load the base N1904-TF package together with the standard N1904addonns. The `mod` argument below pulls the feature files straight from the GitHub repository behind N1904addons so no manual download is needed.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
A = use( "CenterBLC/N1904", version="1.0.0", mod="tonyjurg/N1904addons/tf/", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#gdb630837ae89b9468c9e50d13bda05cfd3de4f18 offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/N1904/app</span>
# <b title="local commit">data:</b> <span title="#gdb630837ae89b9468c9e50d13bda05cfd3de4f18 offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/N1904/tf/1.0.0</span>
# <b title="local commit">data:</b> <span title="#81314a298deed163230c4aa4838ac3ba6b907358 offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/tonyjurg/N1904addons/tf/1.0.0</span>
# <b title="local commit">data:</b> <span title="#81314a298deed163230c4aa4838ac3ba6b907358 offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.6</a>, <a target="_blank" href="https://github.com/CenterBLC/N1904/blob/main/app" title="CenterBLC/N1904 app">CenterBLC/N1904/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/tree/main/docs/about.md" title="provenance of Nestle 1904 Greek New Testament">CenterBLC - N1904 1.0.0</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/greek.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/tree/main/docs/features/README.md" title="CenterBLC - N1904 feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>group</th>
#     <td>8945</td>
#     <td>7.01</td>
#     <td>46</td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>42506</td>
#     <td>8.36</td>
#     <td><i>258</i></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>106868</td>
#     <td>6.88</td>
#     <td><i>533</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>69007</td>
#     <td>1.90</td>
#     <td>95</td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>116178</td>
#     <td>1.60</td>
#     <td><i>135</i></td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b><github>tonyjurg/N1904addons/detailed_set</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_aug1_bc.tf">md10_aug1_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :aug1 line - augment in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_aug1_uc.tf">md10_aug1_uc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :aug1 line - augment in unicode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_case.tf">md10_case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 grammatical case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_degree.tf">md10_degree</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 degree (comparative/superlative)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_dialects.tf">md10_dialects</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 listed dialects</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_end_bc.tf">md10_end_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - ending in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_end_codes.tf">md10_end_codes</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - listed morph codes</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_end_flags.tf">md10_end_flags</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - listed morph flags</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_end_uc.tf">md10_end_uc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - ending in unicode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_gender.tf">md10_gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 grammatical gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_gram_dif.tf">md10_gram_dif</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 grammatical difference against N1904-TF (field)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_lem_base_bc.tf">md10_lem_base_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :lem line - base lemma in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_lem_base_uc.tf">md10_lem_base_uc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :lem line - base lemma in unicode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_lem_full_bc.tf">md10_lem_full_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :lem line - raw lemma (incl. homonym or pl-suffix) in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_lem_full_uc.tf">md10_lem_full_uc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :lem line - raw lemma (incl. homonym or pl-suffix) in unicode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# Display is setup for viewtype [syntax-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/syntax-view.md#start)
# See [here](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/viewtypes.md#start) for more information on viewtypes

# %%
# The following will push the Text-Fabric stylesheet to this notebook (to facilitate proper display with notebook viewer)
A.dh(A.getCss())
# Out:
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c

# %% [markdown]
# # 3 - Step 2: Start at the meta level (`mm*`) <a class="anchor" id="bullet3"></a>
# ##### [Back to ToC](#TOC)

# %% [markdown]
# Suppose we want to understand how many wordforms be derived from a different lemmas. The first step could be to just create a frequency table:

# %%
F.mm_num_lemmas.freqList()
# Out:
# ((1, 78324),
#  (2, 29104),
#  (3, 20501),
#  (4, 5148),
#  (5, 2124),
#  (6, 154),
#  (8, 142),
#  (7, 99),
#  (9, 42),
#  (13, 10),
#  (12, 6),
#  (11, 1))

# %% [markdown]
# Now lets assume we would like to examine the wordforms that migth be derived from - say - exactly 9 lemmas.
# With a very simple TF Query template we can obtain a list of all wordnodes that provide us access to all these wordforms:

# %%
multiLemmaList=A.search("word mm_num_lemmas=9")
# Out:
#   0.08s 42 results

# %% [markdown]
# The TF Query returns a list with 1-tuples which we now can examine further. So the next step is to get a frequency table of the surface forms:

# %%
from collections import Counter

cnt = Counter(
    F.mm_raw_uc.v(wordNode)              # surface form Morpheus analysed
    for (wordNode,) in multiLemmaList    # multiLemmaList is a list of 1-tuples [(wordNode,),]
)

print(f"\nsurface forms that triggered multiple lemma groups:\n")
for surface, freq in cnt.most_common():
    print(f"{surface:<20} {freq:>5}")
# Out:
# surface forms that triggered multiple lemma groups:
#
# Διὰ                     36
# περάτων                  2
# ἀπόλωνται                1
# Δία                      1
# διαπονηθεὶς              1
# διακονιῶν                1

# %% [markdown]
# Now assume we would like to dig deeper into the last wordform, διακονιῶν.
#
# This means that we are looking at an unique occurence of a wordform. There are various methods to identify the value of its wordNode, which is the key to unlock all the data we would like to see. This one is a quick and easy one:

# %%
wordNodeList=A.search("word mm_raw_uc=διακονιῶν")
# Out:
#   0.09s 1 result

# %% [markdown]
# As expected this returns a list with just one tuple. Now we can print some more details:

# %%
for (wordNode,) in wordNodeList:        # wordNodeList is a list of 1-tuples: [(wordNode,),]
    print(f'surface form Morpheus used: {F.mm_raw_uc.v(wordNode)}') 
    print(f'lemma groups found: {F.mm_num_lemmas.v(wordNode)}')
    print(f'Total number of analytic blocks: {F.mm_num_blocks.v(wordNode)}')
# Out:
# surface form Morpheus used: διακονιῶν
# lemma groups found: 9
# Total number of analytic blocks: 15

# %% [markdown]
# # 4 - Step 3: Explore at the summary level (`ms*`)<a class="anchor" id="bullet4"></a>
# ##### [Back to ToC](#TOC)

# %% [markdown]
# To explore these 9 lemmas and their respective grammatical details (like morph code) in detail we need to turn to the summary features. This can easily be done using simple Python code. The real trick in there is the use of a variable name that is constructed dynamicaly in combination with using Text-Fabric's `Fs('fff')` method:
#
# First we exploit the power of the summary features by printing for each lemma the associated morphological tags which provide a very consise summary of all the grammatical detailed created by Morpheus.

# %%
for (wordNode,) in wordNodeList:        # wordNodeList is a list of 1-tuples: [(wordNode,),]
    # How many lemma-groups does this word actually have
    n_lemmas = int(F.mm_num_lemmas.v(wordNode) or 0)

    # loop over the existing groups 1 … n_lemmas
    for index in range(1, n_lemmas + 1):
        lemma   = Fs(f"ms{index}_lem_base_uc").v(wordNode)  # e.g. "ms1_lem_base_uc"
        morph   = Fs(f"ms{index}_morph").v(wordNode)      
        sim     = Fs(f"ms{index}_morph_sim").v(wordNode)   
        print(f"#{index}: lemma={lemma:12}  morph={morph} sim={sim}")
# Out:
# #1: lemma=διακονία      morph=N-GPF sim=100
# #2: lemma=διακόνιον     morph=N-GPN sim=92
# #3: lemma=διά-ἀκονάω    morph=V-PAP-NSM sim=49
# #4: lemma=διά-κονέω     morph=V-PAP-NSM sim=49
# #5: lemma=διά-κονίω     morph=V-PAP-NSM sim=49
# #6: lemma=διά-κονίζω    morph=V-FAP-NSM-ATT sim=49
# #7: lemma=διά-κονιάω    morph=V-PAP-VSM/V-PAP-NSN/V-PAP-VSN/V-PAP-ASN/V-PAP-NSM-ATT/V-IAI-3P/V-IAI-1S sim=49/49/49/49/49/38/25
# #8: lemma=διά-κονιάζω   morph=V-FAP-VSM/V-FAP-NSN/V-FAP-VSN/V-FAP-ASN/V-FAP-NSM-ATT sim=49/49/49/49/49
# #9: lemma=διακονέω      morph=V-PAP-NSM sim=49

# %% [markdown]
# # 5 - Step 4: Deep dive at the detail level (`md*`) <a class="anchor" id="bullet5"></a>
# ##### [Back to ToC](#TOC)

# %% [markdown]
# When we want to dig one level deeper, we should dump the data in feature [`ms{num}_block_nums`](https://tonyjurg.github.io/N1904addons/features/ms%7Bnum%7D_block_nums.html), as this allows us to map the summary features (which are numbered) with their related detailed features (which are also numbered but with a different key).

# %%
for (wordNode,) in wordNodeList:        # wordNodeList is a list of 1-tuples: [(wordNode,),]
    # How many lemma-groups does this word actually have
    n_lemmas = int(F.mm_num_lemmas.v(wordNode) or 0)

    # loop over the existing groups 1 … n_lemmas
    for index in range(1, n_lemmas + 1):
        lemma   = Fs(f"ms{index}_lem_base_uc").v(wordNode)  # e.g. "ms1_lem_base_uc"
        morph   = Fs(f"ms{index}_morph").v(wordNode)      
        sim     = Fs(f"ms{index}_morph_sim").v(wordNode)   
        print(f"#{index}: lemma={lemma:12}  morph={morph} sim={sim}")
# Out:
# #1: lemma=διακονία      morph=N-GPF sim=100
# #2: lemma=διακόνιον     morph=N-GPN sim=92
# #3: lemma=διά-ἀκονάω    morph=V-PAP-NSM sim=49
# #4: lemma=διά-κονέω     morph=V-PAP-NSM sim=49
# #5: lemma=διά-κονίω     morph=V-PAP-NSM sim=49
# #6: lemma=διά-κονίζω    morph=V-FAP-NSM-ATT sim=49
# #7: lemma=διά-κονιάω    morph=V-PAP-VSM/V-PAP-NSN/V-PAP-VSN/V-PAP-ASN/V-PAP-NSM-ATT/V-IAI-3P/V-IAI-1S sim=49/49/49/49/49/38/25
# #8: lemma=διά-κονιάζω   morph=V-FAP-VSM/V-FAP-NSN/V-FAP-VSN/V-FAP-ASN/V-FAP-NSM-ATT sim=49/49/49/49/49
# #9: lemma=διακονέω      morph=V-PAP-NSM sim=49

# %% [markdown]
# Now we can pull from the Morpheus analytic blocks any detailed grammatical property we would like to evaluate.
# But in order to be able to use these detailed features, we need to load them first.

# %%
A.isLoaded("md1_case")
# Out:
# md1_case             NOT LOADED

# %% [markdown]
# The previous cell shows that the detailed dataset is indeed not loaded. To do so. we reload again with inclusion on the detailed dataset:

# %%
A = use( "CenterBLC/N1904", version="1.0.0", mod=["tonyjurg/N1904addons/tf/", "tonyjurg/N1904addons/detailed_set"], hoist=globals(), silence="terse",)
# Out:
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#gdb630837ae89b9468c9e50d13bda05cfd3de4f18 offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/N1904/app</span>
# <b title="local commit">data:</b> <span title="#gdb630837ae89b9468c9e50d13bda05cfd3de4f18 offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/N1904/tf/1.0.0</span>
# <b title="local commit">data:</b> <span title="#7aaa88c755ef9ff13c1841bc7331ea9827d4f7a2 offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/tonyjurg/N1904addons/tf/1.0.0</span>
# <b title="local commit">data:</b> <span title="#7a9b785995288f32000954688f96e8cd19a59438 offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0</span>
#    |     0.00s T md10_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md10_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md10_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md10_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md10_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md10_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md10_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md10_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md10_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md10_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md10_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md10_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md10_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md10_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md10_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md10_workw_bc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md10_workw_uc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md11_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md11_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md11_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md11_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md11_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md11_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md11_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.03s T md11_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md11_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md11_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.03s T md11_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md11_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.03s T md11_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.03s T md11_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_workw_bc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md11_workw_uc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.03s T md12_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.03s T md12_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md12_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_workw_bc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md12_workw_uc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md13_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md13_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md13_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md13_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md13_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md13_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md13_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md13_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md13_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md13_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md13_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_workw_bc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md13_workw_uc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md14_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md14_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md14_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md14_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md14_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md14_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md14_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md14_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md14_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md14_workw_bc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md14_workw_uc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md15_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md15_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md15_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md15_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md15_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md15_workw_bc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md15_workw_uc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md16_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_workw_bc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md16_workw_uc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md17_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md17_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_workw_bc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md17_workw_uc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md18_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md18_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md18_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md18_workw_bc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md18_workw_uc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md19_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.03s T md19_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md19_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md19_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md19_workw_bc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md19_workw_uc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.04s T md1_aug1_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.04s T md1_aug1_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.36s T md1_case             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md1_degree           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.11s T md1_dialects         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.30s T md1_end_bc           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.54s T md1_end_codes        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.32s T md1_end_flags        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.30s T md1_end_uc           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.30s T md1_gender           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.55s T md1_lem_base_bc      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.57s T md1_lem_base_uc      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.54s T md1_lem_full_bc      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.58s T md1_lem_full_uc      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.02s T md1_lem_homonym      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md1_lem_pl_suff      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.13s T md1_mood             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.53s T md1_morph            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md1_morphpart        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.40s T md1_number           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.52s T md1_pos              from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.04s T md1_prvb_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.03s T md1_prvb_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.59s T md1_stem_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.29s T md1_stem_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.31s T md1_stem_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.61s T md1_stem_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.14s T md1_tense            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.13s T md1_voice            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.64s T md1_workw_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.68s T md1_workw_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md20_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_workw_bc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md20_workw_uc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md21_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md21_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md21_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_workw_bc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md21_workw_uc        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md22_aug1_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_aug1_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_case            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_degree          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_dialects        from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_end_bc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_end_codes       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md22_end_flags       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_end_uc          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_gender          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_lem_base_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md22_lem_base_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_lem_full_bc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_lem_full_uc     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_lem_homonym     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md22_lem_pl_suff     from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_mood            from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md22_morph           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md22_morphpart       from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_number          from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_pos             from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md22_prvb_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_prvb_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_stem_bc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.01s T md22_stem_codes      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_stem_flags      from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_stem_uc         from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_tense           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
#    |     0.00s T md22_voice           from ~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0
# ...
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>group</th>
#     <td>8945</td>
#     <td>7.01</td>
#     <td>46</td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>42506</td>
#     <td>8.36</td>
#     <td><i>258</i></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>106868</td>
#     <td>6.88</td>
#     <td><i>533</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>69007</td>
#     <td>1.90</td>
#     <td>95</td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>116178</td>
#     <td>1.60</td>
#     <td><i>135</i></td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b><github>tonyjurg/N1904addons/detailed_set</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_aug1_bc.tf">md10_aug1_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :aug1 line - augment in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_aug1_uc.tf">md10_aug1_uc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :aug1 line - augment in unicode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_case.tf">md10_case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 grammatical case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_degree.tf">md10_degree</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 degree (comparative/superlative)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_dialects.tf">md10_dialects</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 listed dialects</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_end_bc.tf">md10_end_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - ending in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_end_codes.tf">md10_end_codes</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - listed morph codes</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_end_flags.tf">md10_end_flags</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - listed morph flags</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_end_uc.tf">md10_end_uc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - ending in unicode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_ending_bc.tf">md10_ending_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - ending in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_ending_uc.tf">md10_ending_uc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :end line - ending in unicode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_gender.tf">md10_gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 grammatical gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_lem_base_bc.tf">md10_lem_base_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :lem line - base lemma in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_lem_base_uc.tf">md10_lem_base_uc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :lem line - base lemma in unicode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_lem_full_bc.tf">md10_lem_full_bc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Morpheus analytic block 10 :lem line - raw lemma (incl. homonym or pl-suffix) in betacode</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/N1904addons/tree/main/detailed_set" title="~/text-fabric-data/github/tonyjurg/N1904addons/detailed_set/1.0.0/md10_lem_full_uc.tf"
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# Display is setup for viewtype [syntax-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/syntax-view.md#start)
# See [here](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/viewtypes.md#start) for more information on viewtypes

# %% [markdown]
# Now we can create tables using specific part of the Morpheus output. For example aspects like preposition, stem, lemma and ending for each analysis block:

# %%
wordNodeList=A.search("word mm_raw_uc=διακονιῶν")   # we have to re-do this since we reloaded!

for (wordNode,) in wordNodeList:        # wordNodeList is a list of 1-tuples: [(wordNode,),]
    # How many lemma-groups does this word actually have
    n_lemmas = int(F.mm_num_lemmas.v(wordNode) or 0)

    # loop over the existing groups 1 … n_lemmas
    for index in range(1, n_lemmas + 1):
        feat = f"ms{index}_block_nums"          # e.g. "ms1_block_nums"
        block_nums = Fs(feat).v(wordNode)        # Text-Fabric feature lookup
        block_list = block_nums.split('/')
        print(f'index={index}  blocks={block_nums}')
        for block in block_list:
            lem_base_uc = Fs(f"md{block}_lem_base_uc").v(wordNode)
            prvb_uc = Fs(f"md{block}_prvb_uc").v(wordNode)
            stem_uc = Fs(f"md{block}_stem_uc").v(wordNode)
            end_uc = Fs(f"md{block}_end_uc").v(wordNode)
            print(f'{lem_base_uc=}  {stem_uc=}  {end_uc=}')
# Out:
#   0.08s 1 result
# index=1  blocks=1
# lem_base_uc='διακονία'  stem_uc='δια—κονι'  end_uc='ῶν'
# index=2  blocks=2
# lem_base_uc='διακόνιον'  stem_uc='διακονι'  end_uc='ων'
# index=3  blocks=3
# lem_base_uc='διά-ἀκονάω'  stem_uc='ἀκον'  end_uc='ίων'
# index=4  blocks=4
# lem_base_uc='διά-κονέω'  stem_uc='κον'  end_uc='ίων'
# index=5  blocks=5
# lem_base_uc='διά-κονίω'  stem_uc='κονι—'  end_uc='ων'
# index=6  blocks=6
# lem_base_uc='διά-κονίζω'  stem_uc='κονι'  end_uc='ῶν'
# index=7  blocks=7/8/9/10/11
# lem_base_uc='διά-κονιάω'  stem_uc='κονι'  end_uc='ῶν'
# lem_base_uc='διά-κονιάω'  stem_uc='κονι'  end_uc='ῶν'
# lem_base_uc='διά-κονιάω'  stem_uc='κονι'  end_uc='ῶν'
# lem_base_uc='διά-κονιάω'  stem_uc='κονι'  end_uc='ων'
# lem_base_uc='διά-κονιάω'  stem_uc='κονι'  end_uc='ων'
# index=8  blocks=12/13/14
# lem_base_uc='διά-κονιάζω'  stem_uc='κονι'  end_uc='ῶν'
# lem_base_uc='διά-κονιάζω'  stem_uc='κονι'  end_uc='ῶν'
# lem_base_uc='διά-κονιάζω'  stem_uc='κονι'  end_uc='ῶν'
# index=9  blocks=15
# lem_base_uc='διακονέω'  stem_uc='δια—κον'  end_uc='ίων'

# %% [markdown]
# This three-tier approach keeps the usual workflow fast and lightweight (meta + summary only) while it still giving you the option to dive deep whenever your research question demands it.

# %% [markdown]
# # 6 - Making it efficient <a class="anchor" id="bullet6"></a>
# ##### [Back to ToC](#TOC)

# %% [markdown]
# In the previous example, just a few lookups were performed. Access to the detailed features can be made dramaticlay more efficient. In the above situation, Text-Fabric needs to resolve the string name we passed (for example "md7_workw_bc") into an immutable feature object that it knows how to fetch the value for any node. Doing that name-lookup 24 × ≈138 000 word-nodes = about 3.3 million calls.
#
# Especialy if we need to perform such actions multiple times, we can better caching the result once per block, thus making it 24 calls total, and then access it with a simple .v(node) method. This caching can be done using the following code:

# %% [raw]
# BLOCK_RANGE  = range(1, 25)
# lem_base_uc_feat   = {b: Fs(f"md{b}_lem_base_bc")  for b in BLOCK_RANGE}
# prvb_uc_feat       = {b: Fs(f"md{b}_prvb_uc")      for b in BLOCK_RANGE}

# %% [markdown]
# What we created here are just two straight hash-tables `lem_feat[b]` and `workw_feat[b]` (where b is the block number in the range of 1 to 24, inclusive). Now the lookups are very simple to perform:

# %% [raw]
# lem_base_uc  = lem_base_uc_feat[b].v(wordNode)
# prvb_uc      = prvb_uc_feat[b].v(wordNode)

# %% [markdown]
# Putting it all together in a working example where we would like to do something with the combination of lemma and working word for all Morpheus analytic blocks.

# %%
# Once, before the big loop, cache the md* features we would like to access
BLOCK_RANGE  = range(1, 25)
lem_feat     = {b: Fs(f"md{b}_lem_full_bc")  for b in BLOCK_RANGE}
workw_feat   = {b: Fs(f"md{b}_workw_bc")     for b in BLOCK_RANGE}

import time
t0 = time.perf_counter()   # start timer
counter=0

# Now fire up our word nodes loop
for wordNode in F.otype.s("word"):
    # quickly collect (lemma, workw) pairs for this word
    for block in BLOCK_RANGE:
        lem   = lem_feat[block].v(wordNode)
        if not lem:                      # skip empty Morpheus slots fast
            continue
        workw = workw_feat[block].v(wordNode)
        counter +=1
        # do something interesting with (lem, workw) 

elapsed = time.perf_counter() - t0   #stop timer

print(f"Processed {counter:,} lemma–workw pairs in {elapsed:.2f} s ({counter/elapsed:,.0f} pairs/s)")
# Out:
# Processed 361,580 lemma–workw pairs in 0.67 s (535,984 pairs/s)

# %% [markdown]
# The fact that we now have hashable objects opens the door to interesting new analytic usages.
#
# For example to get a list of tuples (wordNode, lem_full_bc) for all cases where the 24th Morpheus analytic block does contain a lemma:

# %%
lem_feat[24].items()
# Out:
# dict_items([(11994, 'e)laia/w'), (14204, 'e)laia/w'), (16185, 'e)laia/w'), (25434, 'e)laia/w'), (26821, 'e)laia/w'), (27825, 'e)laia/w'), (42922, 'dia/,peri/-i(/hmi'), (44695, 'e)laia/w'), (44807, 'e)laia/w'), (46274, 'e)laia/w'), (46880, 'e)laia/w'), (68218, 'a)/llacis'), (78139, 'dia/,a)po/-e)ra/w2'), (82086, 'paraine/w'), (104357, 'a)po/,kata/-la/zomai'), (109819, 'e)n-a)ntia/zw'), (121654, 'katalala/zw')])

# %% [markdown]
# Or, just get the frequencyList:

# %%
lem_feat[24].freqList()
# Out:
# (('e)laia/w', 10),
#  ('a)/llacis', 1),
#  ('a)po/,kata/-la/zomai', 1),
#  ('dia/,a)po/-e)ra/w2', 1),
#  ('dia/,peri/-i(/hmi', 1),
#  ('e)n-a)ntia/zw', 1),
#  ('katalala/zw', 1),
#  ('paraine/w', 1))

# %% [markdown]
# Or just get all the wordNodes that have full_lem_bc='e)laia/w' and the 24th Morpheus analytic block populated.

# %%
lem_feat[24].s('e)laia/w')
# Out:
# (11994, 14204, 16185, 25434, 26821, 27825, 44695, 44807, 46274, 46880)

# %% [markdown]
# Checking what feature is actualy stored under the variable name 'lem_feat' is also easy:

# %%
lem_feat[24].meta['description']
# Out:
# 'Morpheus analytic block 24 :lem line - raw lemma (incl. homonym or pl-suffix) in betacode'

# %% [markdown]
# # 7 - Attribution and footnotes <a class="anchor" id="bullet7"></a>
# ##### [Back to ToC](#TOC)
#
# The [N1904-TF dataset](https://centerblc.github.io/N1904/) is available under the [MIT licence](https://github.com/CenterBLC/N1904/blob/main/LICENSE.md), Copyright (c) 2025 Center of Biblical Languages and Computing (CBLC). Formal reference: Tony Jurg, Saulo de Oliveira Cantanhêde, & Oliver Glanz. (2024). *CenterBLC/N1904: Nestle 1904 Text-Fabric data*. Zenodo. DOI: [10.5281/zenodo.13117911](https://doi.org/10.5281/zenodo.13117910).
#
# The N1904addons Text-Fabric dataset is published at [tonyjurg.github.io/N1904addons](https://tonyjurg.github.io/N1904addons/) and made available under the [Creative Commons Attribution 4.0 International (CC BY 4.0)](https://github.com/tonyjurg/N1904addons/blob/main/LICENSE.md) license.
#
# This Jupyter notebook is released under the [Creative Commons Attribution 4.0 International (CC BY 4.0)](https://github.com/tonyjurg/N1904addons/blob/main/LICENSE.md).

# %% [markdown]
# # 8 - Notebook version<a class="anchor" id="bullet8"></a>
# ##### [Back to ToC](#TOC)
#
# <div style="float: left;">
#   <table>
#     <tr>
#       <td><strong>Author</strong></td>
#       <td>Tony Jurg</td>
#     </tr>
#     <tr>
#       <td><strong>Version</strong></td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <td><strong>Date</strong></td>
#       <td>5 June 2025</td>
#     </tr>
#   </table>
# </div>
